# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitrijLeontev/Dmitrij_Leontev/blob/main/DzDatascience/Dz40_Light_Text_To_Speech_%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D0%B0%D1%83%D0%B4%D0%B8%D0%BE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Установите библиотеку gTTS и с помощью неё синтезируйте аудио следующего текста:
#
#     Многие знают много, но никто не знает всё
#
# Сделайте синтез на трёх языках:
# *   русском (ru)
# *   английском (en)
# *   украинском (uk)
#
# Сам текст ни менять, ни переводить не нужно, меняем только параметр lang='ru'.
#
# Сравните получившиеся аудио и напишите выводы: можно ли таким образом имитировать голоса иностранцев, говорящих на русском языке с акцентом?

# %%
# Ваше решение

# %% [markdown]
# Бесплатная библиотека TTS

# %% [markdown]
# Начнем с ее установки:

# %%
# %%capture

# Бесплатная библиотека Google для задачи TTS
# !pip install gTTS

# %% [markdown]
# Данная библиотека находится в свободном доступе, использование бесплатно. Документация по ссылке: https://gtts.readthedocs.io/en/latest/

# %%
# Импорт библиотеки google-cloud-texttospeech
import gtts

# Основной интерфейс для перевода текста в аудио
from gtts import gTTS

# Используем для проигрывания аудио
from IPython.display import Audio

# %% [markdown]
# Словарь со всеми доступными языками. К сожалению, для русского языка доступен только один голос:

# %%
gtts.lang.tts_langs()
# Out:
# {'af': 'Afrikaans',
#  'ar': 'Arabic',
#  'bg': 'Bulgarian',
#  'bn': 'Bengali',
#  'bs': 'Bosnian',
#  'ca': 'Catalan',
#  'cs': 'Czech',
#  'da': 'Danish',
#  'de': 'German',
#  'el': 'Greek',
#  'en': 'English',
#  'es': 'Spanish',
#  'et': 'Estonian',
#  'fi': 'Finnish',
#  'fr': 'French',
#  'gu': 'Gujarati',
#  'hi': 'Hindi',
#  'hr': 'Croatian',
#  'hu': 'Hungarian',
#  'id': 'Indonesian',
#  'is': 'Icelandic',
#  'it': 'Italian',
#  'iw': 'Hebrew',
#  'ja': 'Japanese',
#  'jw': 'Javanese',
#  'km': 'Khmer',
#  'kn': 'Kannada',
#  'ko': 'Korean',
#  'la': 'Latin',
#  'lv': 'Latvian',
#  'ml': 'Malayalam',
#  'mr': 'Marathi',
#  'ms': 'Malay',
#  'my': 'Myanmar (Burmese)',
#  'ne': 'Nepali',
#  'nl': 'Dutch',
#  'no': 'Norwegian',
#  'pl': 'Polish',
#  'pt': 'Portuguese',
#  'ro': 'Romanian',
#  'ru': 'Russian',
#  'si': 'Sinhala',
#  'sk': 'Slovak',
#  'sq': 'Albanian',
#  'sr': 'Serbian',
#  'su': 'Sundanese',
#  'sv': 'Swedish',
#  'sw': 'Swahili',
#  'ta': 'Tamil',
#  'te': 'Telugu',
#  'th': 'Thai',
#  'tl': 'Filipino',
#  'tr': 'Turkish',
#  'uk': 'Ukrainian',
#  'ur': 'Urdu',
#  'vi': 'Vietnamese',
#  'zh-CN': 'Chinese (Simplified)',
#  'zh-TW': 'Chinese (Mandarin/Taiwan)',
#  'zh': 'Chinese (Mandarin)'}

# %%
# Запишем текст задачи в переменную и синтезируем русскую речь

text = """Многие знают много, но никто не знает всё."""

# Преобразовываем текст в аудио
tts = gTTS(text, lang='ru')

# Сохраняем в формате мр3
tts.save('blok.mp3')

# %%
# Прослушаем полученное аудио
Audio('blok.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Преобразовываем текст в аудио на английском
tts = gTTS(text, lang='en')

# Сохраняем в формате мр3
tts.save('blok.mp3')

# %%
# Прослушаем полученное аудио
Audio('blok.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# перевела половину фразы)
# Попробуем по другому

# %%
# Запишем текст задачи в переменную и синтезируем русскую речь

text = """Many people know a lot, but no one knows everything."""

# Преобразовываем текст в аудио
tts = gTTS(text, lang='ru')

# Сохраняем в формате мр3
tts.save('blok.mp3')

# %%
# Прослушаем полученное аудио
Audio('blok.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Уже лучше:-) правда с акцентом русским, прям беда, но лучше:-)
# Это я так говорю за границей:-)

# %% [markdown]
# Пробуем на украинском языке

# %%
# Запишем текст задачи в переменную и синтезируем русскую речь

text = """Багато хто знає багато, але ніхто не знає все."""

# Преобразовываем текст в аудио
tts = gTTS(text, lang='ru')

# Сохраняем в формате мр3
tts.save('blok.mp3')

# %%
# Прослушаем полученное аудио
Audio('blok.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Короче подойдет:-) Русская девушка говорит на украинском языке. Был там. И примерно также говорил.:-)

# %% [markdown]
# Сравните получившиеся аудио и напишите выводы: можно ли таким образом имитировать голоса иностранцев, говорящих на русском языке с акцентом?

# %% [markdown]
# Ну так себе:-)
# Если после полбутылки водки то все поймем друг друга. :-)
